# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('survey lung cancer.csv')

# %%
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
X_data = data.drop(columns =['LUNG_CANCER','GENDER'], axis= 1)
y_data = data['LUNG_CANCER']

X_data
# Out:
#      AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# 0     69        1               2        2              1                1
# 1     74        2               1        1              1                2
# 2     59        1               1        1              2                1
# 3     63        2               2        2              1                1
# 4     63        1               2        1              1                1
# ..   ...      ...             ...      ...            ...              ...
# 304   56        1               1        1              2                2
# 305   70        2               1        1              1                1
# 306   58        2               1        1              1                1
# 307   67        2               1        2              1                1
# 308   62        1               1        1              2                1
#
#      FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# ...

# %%
plt.figure(figsize=(15, 15))
correlation_matrix = X_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.savefig('correlation-coefficient3.jpg')
plt.show()

# %%
data.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
fig,ax = plt.subplots(figsize =(15,15))
sns.boxplot(data = data, ax = ax)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_data)

# %%
fig,ax = plt.subplots(figsize =(15,15))
sns.boxplot(data = X_scaled, ax = ax)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split( X_data,y_data , test_size =  0.33,random_state = 32)

# %%
X_train.shape
# Out:
# (207, 14)

# %%
X_test.shape
# Out:
# (102, 14)

# %%
y_train.value_counts()
# Out:
# LUNG_CANCER
# YES    181
# NO      26
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state = 42)
X_train_resampled , Y_train_resampled = smote.fit_resample(X_train,y_train)

# %%
print(pd.Series(Y_train_resampled).value_counts())
# Out:
# LUNG_CANCER
# YES    181
# NO     181
# Name: count, dtype: int64

# %%
from sklearn.linear_model  import LogisticRegression
classification = LogisticRegression()
classification.fit(X_train_resampled,Y_train_resampled)
# Out:
# C:\Users\singh\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predict = classification.predict(X_test)
print(y_predict)
# Out:
# ['YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'NO' 'YES' 'YES' 'NO' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES']

# %%
from sklearn.metrics import accuracy_score
accaurate_pred = accuracy_score(y_test,y_predict)
print(accaurate_pred)
# Out:
# 0.9509803921568627

# %% [markdown]
# from sklearn.metrics import classification_report
# target_names = ['cnacer', 'no_cnacer']
# print(classification_report(y_test, y_predict, target_names=target_names))

# %%
import pickle 
pickle.dump(classification,open('classification_model.pkl5','wb'))
